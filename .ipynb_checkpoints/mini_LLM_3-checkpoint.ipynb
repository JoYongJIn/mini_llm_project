# %% [markdown]
# # mini_LLM_2보다 발전한점 : 원하는 정보 챗봇으로 만들어보기

# %% [markdown]
# ## 파일형식으로 작업하는 이유 깨달음(나머지는 그대로 유지한채로 빠르게 필요한 모델들을 부품처럼 불로오기위해 각각의 폴더(학습데이터 폴더, 모델폴더, 토크나이저 폴더, 평가폴더, 가중치폴더, 가중치 저장폴더)에 파일형식으로 관리하는것이다.

# %%
# 학습데이터 이렇게 간단하게 했을때는 질문을 완벽하게 하지않는 이상 대답을 잘하지 못해서 학습데이터를 같은 질문을 다양하게 늘려주는 방법을 택해보았다.
# 아 이렇게 학습데이터나 모델들을 즉각즉각 빠르게 불러와서 이용해보고 저장해놓기위해 파일형식의 개발을 하는것이었구나

text = """
<SOS> <USER> 사자는 어떤 동물이야 <BOT> 사자는 식육목 고양이과 표범속에 속하는 포유류이다 <EOS>

<SOS> <USER> 사자는 왜 백수의 왕이라고 불려 <BOT> 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다 <EOS>

<SOS> <USER> 사자의 아종은 어떻게 나뉘어 <BOT> 사자는 과거 11아종으로 나뉘었지만 현재는 두 아종으로 통합되었다 <EOS>

<SOS> <USER> 사자는 얼마나 커 <BOT> 수컷 사자는 약 175에서 225kg이며 암컷은 약 110에서 143kg 정도이다 <EOS>

<SOS> <USER> 사자는 어디에 살아 <BOT> 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다 <EOS>

<SOS> <USER> 사자는 사회적인 동물이야 <BOT> 사자는 무리 생활을 하는 사회성이 높은 동물이다 <EOS>

<SOS> <USER> 사자의 지능은 어때 <BOT> 사자는 고양이과 동물 중에서도 지능이 높은 편이며 문제 해결 능력이 뛰어나다 <EOS>

<SOS> <USER> 사자는 물을 좋아해 <BOT> 사자는 일반적으로 물을 좋아하지 않지만 일부 지역 사자는 물에서도 생활한다 <EOS>

<SOS> <USER> 사자는 얼마나 빠르게 달려 <BOT> 사자는 최대 약 80km/h까지 달릴 수 있지만 보통은 그보다 느리다 <EOS>

<SOS> <USER> 사자의 울음소리는 얼마나 멀리 가 <BOT> 사자의 포효는 약 8km까지 전달될 수 있다 <EOS>

<SOS> <USER> 사자의 갈기는 왜 있어 <BOT> 갈기는 목을 보호하고 몸을 크게 보이게 하는 역할을 하는 것으로 추정된다 <EOS>

<SOS> <USER> 사자는 왜 수컷만 갈기가 있어 <BOT> 갈기는 성 호르몬의 영향으로 수컷에게만 나타난다 <EOS>

<SOS> <USER> 사자는 하루에 얼마나 쉬어 <BOT> 수컷 사자는 하루의 약 20시간을 쉬며 보낸다 <EOS>

<SOS> <USER> 사자는 누가 사냥해 <BOT> 보통 암사자가 사냥을 담당하고 수사자는 무리를 보호한다 <EOS>

<SOS> <USER> 사자는 왜 멸종 위기야 <BOT> 사자는 서식지 감소와 밀렵으로 인해 개체 수가 감소하고 있다 <EOS>

<SOS> <USER> 사자는 다른 고양이과랑 뭐가 달라 <BOT> 사자는 무리 생활을 하고 개과 동물처럼 행동하는 특징이 있다 <EOS>

<SOS> <USER> 사자는 물속에서도 사냥해 <BOT> 일부 사자는 물속에서도 사냥을 할 수 있다 <EOS>

<SOS> <USER> 사자는 새끼를 어떻게 보호해 <BOT> 수사자는 새끼를 보호하고 외부 적으로부터 방어하는 역할을 한다 <EOS>

<SOS> <USER> 사자의 특징 한줄로 말해줘 <BOT> 사자는 사회성과 힘을 모두 가진 고양이과의 대표적인 맹수이다 <EOS>
"""

# %%
# 이렇게 하니 성능이 확실히 올라갔다.

text = """
<SOS> <USER> 사자는 어떤 동물이야 <BOT> 사자는 식육목 고양이과 표범속에 속하는 포유류이다 <EOS>
<SOS> <USER> 사자는 무슨 동물이야 <BOT> 사자는 식육목 고양이과 표범속에 속하는 포유류이다 <EOS>
<SOS> <USER> 사자는 어떤 동물인지 알려줘 <BOT> 사자는 식육목 고양이과 표범속에 속하는 포유류이다 <EOS>

<SOS> <USER> 사자는 왜 백수의 왕이라고 불려 <BOT> 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다 <EOS>
<SOS> <USER> 사자는 왜 왕이라고 불려 <BOT> 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다 <EOS>
<SOS> <USER> 사자가 백수의 왕인 이유가 뭐야 <BOT> 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다 <EOS>

<SOS> <USER> 사자의 아종은 어떻게 나뉘어 <BOT> 사자는 과거 11아종으로 나뉘었지만 현재는 두 아종으로 통합되었다 <EOS>
<SOS> <USER> 사자는 아종이 몇 개야 <BOT> 사자는 과거 11아종으로 나뉘었지만 현재는 두 아종으로 통합되었다 <EOS>
<SOS> <USER> 사자의 분류는 어떻게 돼 <BOT> 사자는 과거 11아종으로 나뉘었지만 현재는 두 아종으로 통합되었다 <EOS>

<SOS> <USER> 사자는 얼마나 커 <BOT> 수컷 사자는 약 175에서 225kg이며 암컷은 약 110에서 143kg 정도이다 <EOS>
<SOS> <USER> 사자의 크기는 어느 정도야 <BOT> 수컷 사자는 약 175에서 225kg이며 암컷은 약 110에서 143kg 정도이다 <EOS>
<SOS> <USER> 사자는 몸집이 얼마나 커 <BOT> 수컷 사자는 약 175에서 225kg이며 암컷은 약 110에서 143kg 정도이다 <EOS>

<SOS> <USER> 사자는 어디에 살아 <BOT> 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다 <EOS>
<SOS> <USER> 사자는 어디에 서식해 <BOT> 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다 <EOS>
<SOS> <USER> 사자는 어디에 사는 동물이야 <BOT> 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다 <EOS>

<SOS> <USER> 사자는 사회적인 동물이야 <BOT> 사자는 무리 생활을 하는 사회성이 높은 동물이다 <EOS>
<SOS> <USER> 사자는 무리 생활을 해 <BOT> 사자는 무리 생활을 하는 사회성이 높은 동물이다 <EOS>
<SOS> <USER> 사자는 사회성이 있어 <BOT> 사자는 무리 생활을 하는 사회성이 높은 동물이다 <EOS>

<SOS> <USER> 사자의 지능은 어때 <BOT> 사자는 고양이과 동물 중에서도 지능이 높은 편이며 문제 해결 능력이 뛰어나다 <EOS>
<SOS> <USER> 사자는 똑똑해 <BOT> 사자는 고양이과 동물 중에서도 지능이 높은 편이며 문제 해결 능력이 뛰어나다 <EOS>
<SOS> <USER> 사자의 지능 수준은 어때 <BOT> 사자는 고양이과 동물 중에서도 지능이 높은 편이며 문제 해결 능력이 뛰어나다 <EOS>

<SOS> <USER> 사자는 물을 좋아해 <BOT> 사자는 일반적으로 물을 좋아하지 않지만 일부 지역 사자는 물에서도 생활한다 <EOS>
<SOS> <USER> 사자는 물을 싫어해 <BOT> 사자는 일반적으로 물을 좋아하지 않지만 일부 지역 사자는 물에서도 생활한다 <EOS>
<SOS> <USER> 사자는 물에서 생활해 <BOT> 사자는 일반적으로 물을 좋아하지 않지만 일부 지역 사자는 물에서도 생활한다 <EOS>

<SOS> <USER> 사자는 얼마나 빠르게 달려 <BOT> 사자는 최대 약 80km/h까지 달릴 수 있지만 보통은 그보다 느리다 <EOS>
<SOS> <USER> 사자의 속도는 얼마나 돼 <BOT> 사자는 최대 약 80km/h까지 달릴 수 있지만 보통은 그보다 느리다 <EOS>
<SOS> <USER> 사자는 얼마나 빨라 <BOT> 사자는 최대 약 80km/h까지 달릴 수 있지만 보통은 그보다 느리다 <EOS>

<SOS> <USER> 사자의 울음소리는 얼마나 멀리 가 <BOT> 사자의 포효는 약 8km까지 전달될 수 있다 <EOS>
<SOS> <USER> 사자의 포효는 얼마나 멀리 들려 <BOT> 사자의 포효는 약 8km까지 전달될 수 있다 <EOS>
<SOS> <USER> 사자의 울음은 얼마나 멀리 가 <BOT> 사자의 포효는 약 8km까지 전달될 수 있다 <EOS>

<SOS> <USER> 사자의 갈기는 왜 있어 <BOT> 갈기는 목을 보호하고 몸을 크게 보이게 하는 역할을 하는 것으로 추정된다 <EOS>
<SOS> <USER> 사자 갈기의 역할은 뭐야 <BOT> 갈기는 목을 보호하고 몸을 크게 보이게 하는 역할을 하는 것으로 추정된다 <EOS>
<SOS> <USER> 사자는 왜 갈기가 있어 <BOT> 갈기는 목을 보호하고 몸을 크게 보이게 하는 역할을 하는 것으로 추정된다 <EOS>

<SOS> <USER> 사자는 하루에 얼마나 쉬어 <BOT> 수컷 사자는 하루의 약 20시간을 쉬며 보낸다 <EOS>
<SOS> <USER> 사자는 하루에 얼마나 자 <BOT> 수컷 사자는 하루의 약 20시간을 쉬며 보낸다 <EOS>
<SOS> <USER> 사자는 하루 활동 시간이 어떻게 돼 <BOT> 수컷 사자는 하루의 약 20시간을 쉬며 보낸다 <EOS>

<SOS> <USER> 사자는 누가 사냥해 <BOT> 보통 암사자가 사냥을 담당하고 수사자는 무리를 보호한다 <EOS>
<SOS> <USER> 사자는 어떻게 사냥해 <BOT> 보통 암사자가 사냥을 담당하고 수사자는 무리를 보호한다 <EOS>
<SOS> <USER> 사자 무리에서 누가 사냥해 <BOT> 보통 암사자가 사냥을 담당하고 수사자는 무리를 보호한다 <EOS>

<SOS> <USER> 사자는 왜 멸종 위기야 <BOT> 사자는 서식지 감소와 밀렵으로 인해 개체 수가 감소하고 있다 <EOS>
<SOS> <USER> 사자는 왜 개체수가 줄어들어 <BOT> 사자는 서식지 감소와 밀렵으로 인해 개체 수가 감소하고 있다 <EOS>
<SOS> <USER> 사자는 왜 위험해 <BOT> 사자는 서식지 감소와 밀렵으로 인해 개체 수가 감소하고 있다 <EOS>
"""
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# 데이터 폴더에 학습데이터들 txt로 저장해놓고 불러와서 이용하는 방식으로 프로젝트 관리

with open("data/lion.txt", "r", encoding="utf-8") as f: # 다른 폴더에 있어도 내가 띄워놓은 폴더단위에는 들어와있어서 그런지 읽어들여짐
    text = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 데이터 폴더에 학습데이터들 txt로 저장해놓고 불러와서 이용하는 방식으로 프로젝트 관리
# ----> 3 with open("data/lion.txt", "r", encoding="utf-8") as f: # 다른 폴더에 있어도 내가 띄워놓은 폴더단위에는 들어와있어서 그런지 읽어들여짐
#       4     text = f.read()
#
# File ~/miniforge3/envs/research/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/lion.txt'

# %%
tokens = text.split()

vocab = sorted(list(set(tokens)))
UNK = "<UNK>"

if UNK not in vocab:
    vocab.append(UNK)

stoi = {w:i for i,w in enumerate(vocab)}
itos = {i:w for w,i in stoi.items()}

def encode(s):
    return [stoi.get(w, stoi[UNK]) for w in s.split()]

def decode(l):
    return " ".join([itos[i] for i in l])

# %%
import torch

seq_len = 8

data = encode(text)

X, y = [], []

for i in range(len(data) - seq_len):
    X.append(data[i:i+seq_len])
    y.append(data[i+1:i+seq_len+1])

X = torch.tensor(X)
y = torch.tensor(y)

# %%
import torch.nn as nn
import torch.nn.functional as F

def causal_mask(size):
    return torch.tril(torch.ones(size, size))

class SelfAttention(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.q = nn.Linear(d_model, d_model)
        self.k = nn.Linear(d_model, d_model)
        self.v = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, T, D = x.shape

        Q = self.q(x)
        K = self.k(x)
        V = self.v(x)

        scores = Q @ K.transpose(-2, -1) / (D ** 0.5)

        mask = causal_mask(T).to(x.device)
        scores = scores.masked_fill(mask == 0, float('-inf'))

        attn = F.softmax(scores, dim=-1)

        return attn @ V

class Block(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.attn = SelfAttention(d_model)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_model*4),
            nn.ReLU(),
            nn.Linear(d_model*4, d_model)
        )
        self.ln1 = nn.LayerNorm(d_model)
        self.ln2 = nn.LayerNorm(d_model)

    def forward(self, x):
        x = self.ln1(x + self.attn(x))
        x = self.ln2(x + self.ffn(x))
        return x

class GPT(nn.Module):
    def __init__(self, vocab_size, d_model, seq_len):
        super().__init__()
        self.token_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(seq_len, d_model)

        self.blocks = nn.Sequential(
            Block(d_model),
            Block(d_model)
        )

        self.ln = nn.LayerNorm(d_model)
        self.head = nn.Linear(d_model, vocab_size)

    def forward(self, x):
        B, T = x.shape

        tok = self.token_emb(x)
        pos = self.pos_emb(torch.arange(T, device=x.device))

        x = tok + pos
        x = self.blocks(x)
        x = self.ln(x)

        return self.head(x)

# %%
model = GPT(len(vocab), d_model=64, seq_len=seq_len)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

for epoch in range(1000):
    optimizer.zero_grad()

    out = model(X)

    loss = criterion(out.view(-1, len(vocab)), y.view(-1))

    loss.backward()
    optimizer.step()

    if epoch % 50 == 0:
        print(epoch, loss.item())
# Out:
# 0 5.339949131011963
# 50 1.654005527496338
# 100 0.5338334441184998
# 150 0.32112622261047363
# 200 0.2665352523326874
# 250 0.2421550154685974
# 300 0.23096445202827454
# 350 0.22579394280910492
# 400 0.2223498374223709
# 450 0.2210969179868698
# 500 0.21869884431362152
# 550 0.21757619082927704
# 600 0.2169455587863922
# 650 0.21605810523033142
# 700 0.215438112616539
# 750 0.21504510939121246
# 800 0.21503223478794098
# 850 0.2146534025669098
# 900 0.214064821600914
# 950 0.21391168236732483

# %%
import torch.nn.functional as F

def generate(model, prompt, max_len=20, temperature=1.0):
    model.eval()

    tokens = encode(prompt)

    for _ in range(max_len):
        x = torch.tensor(tokens[-seq_len:]).unsqueeze(0)

        out = model(x)
        logits = out[0, -1] / temperature

        probs = F.softmax(logits, dim=0)

        next_token = torch.multinomial(probs, 1).item()

        tokens.append(next_token)

        if itos[next_token] == "<EOS>":
            break

    return decode(tokens)

# %%
prompt = "<SOS> <USER> 오늘 날씨 어때 <BOT>"

print(generate(model, prompt, temperature=0.8))

# %%
def chat(model):
    print("챗봇 시작 (종료: exit 입력)")

    while True:
        user_input = input("User: ")

        if user_input.lower() == "exit":
            break

        prompt = f"<SOS> <USER> {user_input} <BOT>"

        output = generate(model, prompt, temperature=0.8)

        # <BOT> 이후만 잘라서 출력
        response = output.split("<BOT>")[-1]
        response = response.replace("<EOS>", "").strip()

        print("Bot:", response)

# %%
chat(model)
# Out:
# 챗봇 시작 (종료: exit 입력)
# User:  사자는 어떤 동물이야?
# Bot: 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다
# User:  사자 다리가 몇개니
# Bot: 갈기는 목을 보호하고 몸을 크게 보이게 하는 역할을 하는 것으로 추정된다
# User:  사자는 얼마나커?
# Bot: 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다
# User:  사자사자는 어디에 살아
# Bot: 사자는 주로 사하라 이남 아프리카 사바나에 서식하고 인도 기르 숲에도 일부 서식한다
# User:  사자는 왜 멸종 위기야
# Bot: 사자는 서식지 감소와 밀렵으로 인해 개체 수가 감소하고 있다
# User:  사자에 대해 설명해봐
# Bot: 사자는 무리 생활을 하는 사회성이 높은 동물이다
# User:  사자의 지능은 어떄
# Bot: 사자는 강력한 힘과 갈기로 용맹한 이미지가 있어 백수의 왕으로 불린다
# User:  사자의 지능은 어때
# Bot: 사자는 고양이과 동물 중에서도 지능이 높은 편이며 문제 해결 능력이 뛰어나다
# User:  exit
